# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# importing library
export_path = r'C:/Users/User/Downloads/4.3_orders_products/02-Data/Prepared-Data'
file_name = 'ords_prods_merge.pkl'

# %%
# Load the pickle file into a DataFrame
ords_prods_merge = pd.read_pickle(os.path.join(export_path, file_name))

# %%
# creating a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# define function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7428\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    674229
# Low-range product    312859
# High range            12912
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                   21186631
# Low-range product     10126321
# Mid-range product       674229
# High-range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# order_dow
# 0    2115379
# 1    1969233
# 6    1540467
# 2    1469722
# 5    1467625
# 3    1337563
# 4    1318239
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge.loc[:, 'busiest day'] = result

# %%
ords_prods_merge.loc[:, 'busiest day'].value_counts(dropna = False)
# Out:
# busiest day
# Regularly busy    7784610
# Busiest day       2115379
# Least busy        1318239
# Name: count, dtype: int64

# %% [markdown]
# # Busiest days

# %%
# Use a "for-loop" to create a new column for "busiest_days" where the "Busiest days" = the two busiest days of the week
# The two slowest days of the week = "Slowest days"
busiest_days = []
for value in ords_prods_merge["order_dow"]:
    if value == 0 or value == 1:
        busiest_days.append("Busiest days")
    elif value == 3 or value == 4:
        busiest_days.append("Slowest days")
    else:
        busiest_days.append("Regular days")

# %%
ords_prods_merge['busiest_days'] = busiest_days

# %%
# Use the "value_counts" function to check the new "busiest_days" column
ords_prods_merge['busiest_days'].value_counts(dropna = False)

# %% [markdown]
#                                            Observation
#
# There is a distribution of order_dow with new columns "Busiest days," "Slowest days," and "Regular day."

# %%
# Check value counts in "order_hour_of_day" column.

ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    963910
# 11    952175
# 14    929107
# 13    920575
# 15    919520
# 12    909366
# 16    874316
# 9     855959
# 17    721331
# 8     595649
# 18    564743
# 19    433761
# 20    336668
# 7     306182
# 21    273424
# 22    217582
# 23    138605
# 6      99938
# 0      75458
# 1      39863
# 5      30097
# 2      24262
# 4      18156
# 3      17581
# Name: count, dtype: int64

# %% [markdown]
# The value counts listed above will be split into equal thirds for the following labels: "Most orders" = 10, 11, 14, 15, 13, 12, 16, and 9; "Fewest orders" = 23, 6, 0, 1, 5, 2, 4, and 3; "Average orders" = all remaining values in order_hour_of_day.

# %%
# Create for-loop if statement labeling periods of time as “Most orders,” “Average orders,” and “Fewest orders.”

result_3 = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    result_3.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    result_3.append("Fewest orders")
  else:
    result_3.append("Average orders")

# %%
result_3
# Out:
# ['Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Create new column "busiest_period_of_day" in ords_prods_merge.

ords_prods_merge['busiest_period_of_day'] = result_3
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7428\2997588503.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ords_prods_merge['busiest_period_of_day'] = result_3

# %%
# Create new column "busiest_period_of_day" in ords_prods_merge
ords_prods_merge.loc[:, 'busiest_period_of_day'] = result_3

# %% [markdown]
# # Export dataframe as a pickle file to “Prepared Data” folder.

# %%
# Define the base directory
path = r"C:\your\base\directory"

# %%
# Ensure the directory exists
output_dir = os.path.join(path, '02 Data', 'Prepared Data')
os.makedirs(output_dir, exist_ok=True)

# %%
# Save the DataFrame to a pickle file
ords_prods_merge.to_pickle(os.path.join(output_dir, 'ords_prods_merge_derived.pkl'))
